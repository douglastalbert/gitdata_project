# %%
import pyspark.sql
from pyspark.sql.types import StructField, StringType, IntegerType, StructType, ArrayType, BooleanType, TimestampType, DataType

dbutils.widgets.text("Repository", "REPOSITORY")
getArgument("Repository")
df_schema=StructField('repo',StringType(),True),StructField('user',StringType(),True),StructField('state',StringType(),True),StructField('url',StringType(),True),StructField('created',TimestampType(),True),StructField('updated',TimestampType(),True),StructField('closed',TimestampType(),True),StructField('assignees',ArrayType(StringType()),True),StructField('reviewers',ArrayType(StringType()),True),StructField('review_teams',ArrayType(StringType()),True),StructField('labels',ArrayType(StringType()),True),StructField('branch',StringType(),True),StructField('merged',BooleanType(),True),StructField('comments',IntegerType(),True),StructField('review_comments',IntegerType(),True),StructField('commits',IntegerType(),True),StructField('additions',IntegerType(),True),StructField('deletions',IntegerType(),True),StructField('changed_files',IntegerType(),True)

df_schema = StructType(fields=df_schema)

raw = spark.read.json('FileStore/tables/output.json',schema=df_schema)
display(raw.filter(raw.state=='open'))
# raw.describe().show()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>repo</th><th>user</th><th>state</th><th>url</th><th>created</th><th>updated</th><th>closed</th><th>assignees</th><th>reviewers</th><th>review_teams</th><th>labels</th><th>branch</th><th>merged</th><th>comments</th><th>review_comments</th><th>commits</th><th>additions</th><th>deletions</th><th>changed_files</th></tr></thead><tbody><tr><td>ApiWrapper</td><td>dependabot[bot]</td><td>open</td><td>https://api.github.com/repos/syapse/ApiWrapper/pulls/178</td><td>2019-06-28T22:35:08.000+0000</td><td>2019-06-28T22:35:09.000+0000</td><td>null</td><td>List()</td><td>List()</td><td>List()</td><td>List(dependencies)</td><td>dependabot/pip/requests-2.20.0</td><td>false</td><td>0</td><td>0</td><td>1</td><td>1</td><td>1</td><td>1</td></tr><tr><td>ApiWrapper</td><td>dependabot[bot]</td><td>open</td><td>https://api.github.com/repos/syapse/ApiWrapper/pulls/177</td><td>2019-06-28T22:35:05.000+0000</td><td>2019-06-28T22:35:06.000+0000</td><td>null</td><td>List()</td><td>List()</td><td>List()</td><td>List(dependencies)</td><td>dependabot/pip/django-1.11.21</td><td>false</td><td>0</td><td>0</td><td>1</td><td>1</td><td>1</td><td>1</td></tr><tr><td>Apps</td><td>dependabot-preview[bot]</td><td>open</td><td>https://api.github.com/repos/syapse/Apps/pulls/8627</td><td>2019-07-23T19:05:33.000+0000</td><td>2019-07-23T19:05:36.000+0000</td><td>null</td><td>List()</td><td>List()</td><td>List()</td><td>List(dependencies)</td><td>dependabot/pip/mako-1.0.14</td><td>false</td><td>2</td><td>0</td><td>1</td><td>135</td><td>2</td><td>2</td></tr><tr><td>Apps</td><td>dependabot-preview[bot]</td><td>open</td><td>https://api.github.com/repos/syapse/Apps/pulls/8626</td><td>2019-07-22T21:30:04.000+0000</td><td>2019-07-22T21:30:07.000+0000</td><td>null</td><td>List()</td><td>List()</td><td>List()</td><td>List(dependencies)</td><td>dependabot/pip/pyparsing-2.4.1</td><td>false</td><td>2</td><td>0</td><td>1</td><td>228</td><td>4</td><td>4</td></tr><tr><td>Apps</td><td>dependabot-preview[bot]</td><td>open</td><td>https://api.github.com/repos/syapse/Apps/pulls/8625</td><td>2019-07-22T21:29:01.000+0000</td><td>2019-07-22T21:29:04.000+0000</td><td>null</td><td>List()</td><td>List()</td><td>List()</td><td>List(dependencies)</td><td>dependabot/pip/sqlalchemy-1.3.6</td><td>false</td><td>2</td><td>0</td><td>1</td><td>135</td><td>2</td><td>2</td></tr><tr><td>Apps</td><td>dependabot-preview[bot]</td><td>open</td><td>https://api.github.com/repos/syapse/Apps/pulls/8620</td><td>2019-07-19T22:12:14.000+0000</td><td>2019-07-19T22:12:16.000+0000</td><td>null</td><td>List()</td><td>List()</td><td>List()</td><td>List(dependencies)</td><td>dependabot/pip/django-extensions-2.2.1</td><td>false</td><td>2</td><td>0</td><td>1</td><td>135</td><td>2</td><td>2</td></tr><tr><td>Apps</td><td>denniscieri</td><td>open</td><td>https://api.github.com/repos/syapse/Apps/pulls/8611</td><td>2019-07-15T18:29:53.000+0000</td><td>2019-07-24T20:31:02.000+0000</td><td>null</td><td>List()</td><td>List()</td><td>List()</td><td>List()</td><td>feature/create_lab_script_to_clear_all_syckb_hasTherapy</td><td>false</td><td>0</td><td>3</td><td>7</td><td>83</td><td>0</td><td>1</td></tr><tr><td>Apps</td><td>dependabot[bot]</td><td>open</td><td>https://api.github.com/repos/syapse/Apps/pulls/8610</td><td>2019-07-12T23:19:49.000+0000</td><td>2019-07-17T19:01:47.000+0000</td><td>null</td><td>List()</td><td>List()</td><td>List()</td><td>List(dependencies, javascript)</td><td>dependabot/npm_and_yarn/client/lodash-4.17.13</td><td>false</td><td>3</td><td>0</td><td>1</td><td>4</td><td>8</td><td>2</td></tr><tr><td>Apps</td><td>kojiromike</td><td>open</td><td>https://api.github.com/repos/syapse/Apps/pulls/8609</td><td>2019-07-12T14:08:25.000+0000</td><td>2019-07-25T16:58:12.000+0000</td><td>null</td><td>List(kojiromike)</td><td>List()</td><td>List()</td><td>List()</td><td>logging</td><td>false</td><td>1</td><td>8</td><t ...

# %%
#The user and repository with metrics to be charted
# USER_FOR_METRICS = getArgument("User")
REPOSITORY_FOR_METRICS = getArgument("Repository")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.sql import functions, Row, Column
raw = raw.withColumn('closed', functions.when(raw.closed.isNull(), functions.current_timestamp()).otherwise(raw.closed))
duration = functions.unix_timestamp(raw.closed) - functions.unix_timestamp(raw.created)

processed_data = raw.withColumn('age', duration)
# processed_data.show()
# print(processed_data.count())
# display(processed_data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Finds number of rows in which url (id) appears, generating count for number of review teams
df1 = raw.withColumn('exploded_review_team',functions.explode(raw.review_teams))

num_teams = df1.groupBy(df1.url).count()
num_teams = num_teams.withColumnRenamed('count','team_count').withColumnRenamed('url','URL')

processed_data = processed_data.join(num_teams, processed_data.url==num_teams.URL, "left")
# display(processed_data)
#Not finished
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Displays Open PR Ages Chart 
chart1_dataframe = processed_data.withColumn("age_in_days", processed_data.age/86400)
# chart1_dataframe = chart1_dataframe.filter(chart1_dataframe.age_in_days<=30)
chart1_dataframe = chart1_dataframe.filter(chart1_dataframe.repo == REPOSITORY_FOR_METRICS)
chart1_dataframe = chart1_dataframe.sort(chart1_dataframe.user.desc())
display(chart1_dataframe.filter(chart1_dataframe.state=='open'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>repo</th><th>user</th><th>state</th><th>url</th><th>created</th><th>updated</th><th>closed</th><th>assignees</th><th>reviewers</th><th>review_teams</th><th>labels</th><th>branch</th><th>merged</th><th>comments</th><th>review_comments</th><th>commits</th><th>additions</th><th>deletions</th><th>changed_files</th><th>age</th><th>URL</th><th>team_count</th><th>age_in_days</th></tr></thead><tbody></tbody></table></div>

# %%
chart2_dataframe = chart1_dataframe.withColumn('seconds_since_creation', functions.unix_timestamp(functions.current_timestamp()) - functions.unix_timestamp(chart1_dataframe.created))
chart2_dataframe = chart2_dataframe.withColumn('weeks_since_creation', chart2_dataframe.seconds_since_creation / 604800)
chart2_dataframe = chart2_dataframe.withColumn('weeks_ago',chart2_dataframe.weeks_since_creation.cast(IntegerType()))
chart2_dataframe = chart2_dataframe.sort(chart2_dataframe.weeks_ago.desc())
display(chart2_dataframe)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>repo</th><th>user</th><th>state</th><th>url</th><th>created</th><th>updated</th><th>closed</th><th>assignees</th><th>reviewers</th><th>review_teams</th><th>labels</th><th>branch</th><th>merged</th><th>comments</th><th>review_comments</th><th>commits</th><th>additions</th><th>deletions</th><th>changed_files</th><th>age</th><th>URL</th><th>team_count</th><th>age_in_days</th><th>seconds_since_creation</th><th>weeks_since_creation</th><th>weeks_ago</th></tr></thead><tbody><tr><td>provenance-python-client</td><td>katyberg</td><td>closed</td><td>https://api.github.com/repos/syapse/provenance-python-client/pulls/1</td><td>2019-03-06T18:09:59.000+0000</td><td>2019-03-11T19:50:47.000+0000</td><td>2019-03-11T19:48:19.000+0000</td><td>List()</td><td>List(gabrielsyapse)</td><td>List()</td><td>List()</td><td>feat/AP_34422_initial_skeleton</td><td>true</td><td>1</td><td>15</td><td>17</td><td>1715</td><td>1</td><td>36</td><td>437900</td><td>null</td><td>null</td><td>5.068287037037037</td><td>12779356</td><td>21.129887566137565</td><td>21</td></tr><tr><td>provenance-python-client</td><td>katyberg</td><td>closed</td><td>https://api.github.com/repos/syapse/provenance-python-client/pulls/2</td><td>2019-03-13T21:50:05.000+0000</td><td>2019-03-15T17:29:47.000+0000</td><td>2019-03-15T16:45:42.000+0000</td><td>List()</td><td>List()</td><td>List()</td><td>List()</td><td>feat/AP_34702_json_serialization</td><td>true</td><td>3</td><td>6</td><td>12</td><td>609</td><td>281</td><td>11</td><td>154537</td><td>null</td><td>null</td><td>1.7886226851851852</td><td>12161350</td><td>20.10805224867725</td><td>20</td></tr><tr><td>provenance-python-client</td><td>katyberg</td><td>closed</td><td>https://api.github.com/repos/syapse/provenance-python-client/pulls/3</td><td>2019-03-19T03:34:01.000+0000</td><td>2019-03-24T01:54:16.000+0000</td><td>2019-03-20T17:24:40.000+0000</td><td>List()</td><td>List(gabrielsyapse)</td><td>List()</td><td>List()</td><td>feat/AP_34698_stream_kinesis</td><td>true</td><td>0</td><td>16</td><td>3</td><td>243</td><td>14</td><td>10</td><td>136239</td><td>null</td><td>null</td><td>1.5768402777777777</td><td>11708714</td><td>19.359646164021164</td><td>19</td></tr><tr><td>provenance-python-client</td><td>katyberg</td><td>closed</td><td>https://api.github.com/repos/syapse/provenance-python-client/pulls/4</td><td>2019-03-24T02:37:50.000+0000</td><td>2019-05-21T20:23:01.000+0000</td><td>2019-03-25T05:48:53.000+0000</td><td>List()</td><td>List(gabrielsyapse)</td><td>List()</td><td>List()</td><td>bumpversion_to_0.2.0-rc1</td><td>true</td><td>0</td><td>0</td><td>1</td><td>6</td><td>7</td><td>3</td><td>97863</td><td>null</td><td>null</td><td>1.132673611111111</td><td>11280085</td><td>18.650934193121692</td><td>18</td></tr><tr><td>provenance-python-client</td><td>katyberg</td><td>closed</td><td>https://api.github.com/repos/syapse/provenance-python-client/pulls/6</td><td>2019-04-18T05:07:17.000+0000</td><td>2019-05-21T20:22:55.000+0000</td><td>2019-04-18T20:43:03.000+0000</td><td>List()</td><td>List()</td><td>List()</td><td>List()</td><td>feat/AP_36034_prepare_for_usability_testing</td><td>true</td><td>0</td><td>4</td><td>6</td><td>179</td><td>56</td><td>9</td><td>56146</td><td>null</td><td>null</td><td>0.6498379629629629</td><td>9111118</td><td>15.064679232804233</td><td>15</td></tr><tr><td>provenance-python-client</td><td>katyberg</td><td>closed</td><td>https://api.github.com/repos/syapse/provenance-python-client/pulls/5</td><td>2019-04-16T23:38:42.000+0000</td><td>2019-05-21T20:22:58.000+0000</td><td>2019-04-17T17:20:13.000+0000</td><td>List()</td><td>List()</td><td>List()</td><td>List()</td><td>bugfix/AP_35751_fix_client_bug</td><td>true</td><td>1</td><td>0</td><td>4</td><td>748</td><td>207</td><td>14</td><td>63691</td><td>null</td><td>null</td><td>0.7371643518518518</td><td>9217233</td><td>15.240133928571428</td><td>15</td></tr><tr ...

# %%
# #Create line graph for commits by week for user
# chart2_dataframe = chart1_dataframe.withColumn('seconds_since_creation', functions.unix_timestamp(functions.current_timestamp()) - functions.unix_timestamp(chart1_dataframe.created))
# chart2_dataframe = chart2_dataframe.withColumn('weeks_since_creation', chart2_dataframe.seconds_since_creation / 604800)
# chart2_dataframe = chart2_dataframe.withColumn('weeks_ago',chart2_dataframe.weeks_since_creation.cast(IntegerType()))

# chart2_dataframe = chart2_dataframe.filter(chart2_dataframe.weeks_ago < 14)
# chart2_dataframe = chart2_dataframe.sort(chart2_dataframe.weeks_ago.desc())
# display(chart2_dataframe.filter(chart2_dataframe.user == USER_FOR_METRICS))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# display(chart2_dataframe.filter(chart2_dataframe.user == USER_FOR_METRICS))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Create histogram for pr close time by repository
chart3_dataframe = chart1_dataframe.filter(chart1_dataframe.state == 'closed').filter(chart1_dataframe.repo == REPOSITORY_FOR_METRICS)
display(chart3_dataframe.withColumnRenamed('age_in_days','days_before_closed'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>repo</th><th>user</th><th>state</th><th>url</th><th>created</th><th>updated</th><th>closed</th><th>assignees</th><th>reviewers</th><th>review_teams</th><th>labels</th><th>branch</th><th>merged</th><th>comments</th><th>review_comments</th><th>commits</th><th>additions</th><th>deletions</th><th>changed_files</th><th>age</th><th>URL</th><th>team_count</th><th>days_before_closed</th></tr></thead><tbody><tr><td>provenance-python-client</td><td>katyberg</td><td>closed</td><td>https://api.github.com/repos/syapse/provenance-python-client/pulls/8</td><td>2019-05-19T07:08:11.000+0000</td><td>2019-05-21T20:22:53.000+0000</td><td>2019-05-20T21:39:36.000+0000</td><td>List()</td><td>List()</td><td>List()</td><td>List()</td><td>feat/AP_37337_client_beta</td><td>true</td><td>0</td><td>13</td><td>8</td><td>477</td><td>1200</td><td>24</td><td>138685</td><td>null</td><td>null</td><td>1.605150462962963</td></tr><tr><td>provenance-python-client</td><td>katyberg</td><td>closed</td><td>https://api.github.com/repos/syapse/provenance-python-client/pulls/6</td><td>2019-04-18T05:07:17.000+0000</td><td>2019-05-21T20:22:55.000+0000</td><td>2019-04-18T20:43:03.000+0000</td><td>List()</td><td>List()</td><td>List()</td><td>List()</td><td>feat/AP_36034_prepare_for_usability_testing</td><td>true</td><td>0</td><td>4</td><td>6</td><td>179</td><td>56</td><td>9</td><td>56146</td><td>null</td><td>null</td><td>0.6498379629629629</td></tr><tr><td>provenance-python-client</td><td>katyberg</td><td>closed</td><td>https://api.github.com/repos/syapse/provenance-python-client/pulls/11</td><td>2019-07-16T21:02:43.000+0000</td><td>2019-07-19T01:38:00.000+0000</td><td>2019-07-19T01:37:59.000+0000</td><td>List()</td><td>List()</td><td>List()</td><td>List()</td><td>AP_37118_Sequence_diagrams</td><td>true</td><td>0</td><td>0</td><td>1</td><td>198</td><td>0</td><td>6</td><td>189316</td><td>null</td><td>null</td><td>2.1911574074074074</td></tr><tr><td>provenance-python-client</td><td>katyberg</td><td>closed</td><td>https://api.github.com/repos/syapse/provenance-python-client/pulls/4</td><td>2019-03-24T02:37:50.000+0000</td><td>2019-05-21T20:23:01.000+0000</td><td>2019-03-25T05:48:53.000+0000</td><td>List()</td><td>List(gabrielsyapse)</td><td>List()</td><td>List()</td><td>bumpversion_to_0.2.0-rc1</td><td>true</td><td>0</td><td>0</td><td>1</td><td>6</td><td>7</td><td>3</td><td>97863</td><td>null</td><td>null</td><td>1.132673611111111</td></tr><tr><td>provenance-python-client</td><td>katyberg</td><td>closed</td><td>https://api.github.com/repos/syapse/provenance-python-client/pulls/3</td><td>2019-03-19T03:34:01.000+0000</td><td>2019-03-24T01:54:16.000+0000</td><td>2019-03-20T17:24:40.000+0000</td><td>List()</td><td>List(gabrielsyapse)</td><td>List()</td><td>List()</td><td>feat/AP_34698_stream_kinesis</td><td>true</td><td>0</td><td>16</td><td>3</td><td>243</td><td>14</td><td>10</td><td>136239</td><td>null</td><td>null</td><td>1.5768402777777777</td></tr><tr><td>provenance-python-client</td><td>katyberg</td><td>closed</td><td>https://api.github.com/repos/syapse/provenance-python-client/pulls/2</td><td>2019-03-13T21:50:05.000+0000</td><td>2019-03-15T17:29:47.000+0000</td><td>2019-03-15T16:45:42.000+0000</td><td>List()</td><td>List()</td><td>List()</td><td>List()</td><td>feat/AP_34702_json_serialization</td><td>true</td><td>3</td><td>6</td><td>12</td><td>609</td><td>281</td><td>11</td><td>154537</td><td>null</td><td>null</td><td>1.7886226851851852</td></tr><tr><td>provenance-python-client</td><td>katyberg</td><td>closed</td><td>https://api.github.com/repos/syapse/provenance-python-client/pulls/1</td><td>2019-03-06T18:09:59.000+0000</td><td>2019-03-11T19:50:47.000+0000</td><td>2019-03-11T19:48:19.000+0000</td><td>List()</td><td>List(gabrielsyapse)</td><td>List()</td><td>List()</td><td>feat/AP_34422_initial_skeleton</td><td>true</td><td>1</td><td>15</td><td>17</td><td>1715< ...

# %%
# display(chart1_dataframe.sort(chart1_dataframe.commits.desc()))
chart4_dataframe = chart1_dataframe.groupBy("user").count()
chart4_dataframe = chart4_dataframe.withColumnRenamed("count","pull_requests")
display(chart4_dataframe.sort(chart4_dataframe.pull_requests.desc()))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>user</th><th>pull_requests</th></tr></thead><tbody><tr><td>katyberg</td><td>9</td></tr><tr><td>gabrielsyapse</td><td>1</td></tr><tr><td>gianlucabiccari</td><td>1</td></tr></tbody></table></div>
